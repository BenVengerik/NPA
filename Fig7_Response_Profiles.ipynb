# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from pathlib import Path

# =========================================================
# 1. CONFIGURATION
# =========================================================

STIM = "tail" 

TARGETS = [
    ("a2",   "brush_" + STIM),  
    ("pup1", "brush_" + STIM),
    ("pup2", "brush_" + STIM) 
]

MAX_TRIALS = 8      
PRE_WINDOW = 0.5    
POST_WINDOW = 1.5 

ANIMAL_COLORS = {
    "a2":   "#FA91A8",  # Pink
    "pup1": "#A8FA91",  # Green
    "pup2": "#91FAC5"   # Mint
}

# --- NEW: Presentation Ready Names ---
ANIMAL_NAMES = {
    "a2":   "Adult",
    "pup1": "Pup 1",
    "pup2": "Pup 2"
}

# =========================================================
# 2. DATA PROCESSING
# =========================================================
trial_data = []
csv_path = Path("data/sessions_local.csv") if Path("data/sessions_local.csv").exists() else Path("data/sessions.csv")
meta = pd.read_csv(csv_path)

print(f"{'='*60}")
print(f"GENERATING PUBLICATION PLOT: {STIM}")
print(f"{'='*60}")

for session, stim in TARGETS:
    row = meta.loc[(meta['session'] == session) & (meta['stim'] == stim)]
    if len(row) == 0: continue
    row = row.iloc[0]
    
    onsets_path = Path(f"results/summaries/{session}_{stim}_onsets.txt")
    if not onsets_path.exists(): continue
    onsets = np.loadtxt(onsets_path)
    if onsets.ndim == 0: onsets = [onsets]
    
    onsets = np.sort(onsets)
    current_trials = onsets[:MAX_TRIALS]
    
    phy_dir = Path(row['phy_dir'])
    spike_times = np.load(phy_dir / 'spike_times.npy').flatten() / 30000.0
    spike_clusters = np.load(phy_dir / 'spike_clusters.npy').flatten()
    cluster_info = pd.read_csv(phy_dir / 'cluster_info.tsv', sep='\t')
    
    lbl = 'KSLabel' if 'KSLabel' in cluster_info.columns else 'group'
    valid_units = cluster_info[cluster_info[lbl].isin(['good', 'mua'])]
    
    def get_bound(col): return float(row[col]) if col in row and not pd.isna(row[col]) else None
    l1_bot  = get_bound('l1_end')
    l23_bot = get_bound('l23_end')
    l4_bot  = get_bound('l4_end')
    l6_bot  = get_bound('l6_end')
    if l1_bot is None: l1_bot = get_bound('s1_upper_um')

    for _, unit in valid_units.iterrows():
        uid = unit['cluster_id']
        depth = unit['depth']
        
        layer = "Other"
        if l23_bot is not None and l1_bot is not None and l23_bot <= depth <= l1_bot: layer = "L2/3"
        if l4_bot is not None and l23_bot is not None and l4_bot <= depth < l23_bot: layer = "L4"
        if l6_bot is not None and l4_bot is not None and l6_bot <= depth < l4_bot: layer = "L5/6"

        if layer not in ['L4', 'L5/6']: continue
        
        u_spikes = spike_times[spike_clusters == uid]
        
        for i, t in enumerate(current_trials):
            trial_idx = i + 1 
            c_pre = np.sum((u_spikes >= t - PRE_WINDOW) & (u_spikes < t))
            c_post = np.sum((u_spikes >= t) & (u_spikes < t + POST_WINDOW))
            evoked = (c_post / POST_WINDOW) - (c_pre / PRE_WINDOW)
            
            trial_data.append({
                'Animal': session,
                'Layer': layer,
                'Trial': trial_idx,
                'Evoked_Hz': evoked
            })

# =========================================================
# 3. PLOTTING & SAVING
# =========================================================

# --- Global Font Settings ---
FONT_SIZE = 10
TITLE_SIZE = 11
plt.rcParams.update({
    'font.size': FONT_SIZE,
    'font.family': 'Arial',  # Most journals prefer Arial or Helvetica
    'axes.titlesize': TITLE_SIZE,
    'axes.labelsize': FONT_SIZE,
    'xtick.labelsize': FONT_SIZE - 1,
    'ytick.labelsize': FONT_SIZE - 1,
})

if len(trial_data) == 0:
    print("ERROR: No units found. Check data paths and layer bounds.")
else:
    df = pd.DataFrame(trial_data)

    # --- Calculate Mean and SEM per Layer / Animal / Trial ---
    mean_df = df.groupby(['Layer', 'Animal', 'Trial'])['Evoked_Hz'].mean().reset_index()
    sem_df  = df.groupby(['Layer', 'Animal', 'Trial'])['Evoked_Hz'].sem().reset_index()
    plot_df = mean_df.merge(sem_df, on=['Layer', 'Animal', 'Trial'], suffixes=('_mean', '_sem'))

    animals = ['a2', 'pup1', 'pup2']
    layers  = ['L4', 'L5/6']

    sns.set_style("ticks")

    # --- Figure size: 183mm double-column width ---
    fig, axes = plt.subplots(3, 2, figsize=(7.2, 9), sharex=True, sharey='col')

    for row_idx, animal in enumerate(animals):
        for col_idx, layer in enumerate(layers):
            ax = axes[row_idx, col_idx]
            panel_idx = row_idx * 2 + col_idx

            subset = plot_df[(plot_df['Animal'] == animal) & (plot_df['Layer'] == layer)]
            n_count = len(df[(df['Animal'] == animal) & (df['Layer'] == layer) & (df['Trial'] == 1)])
            color = ANIMAL_COLORS[animal]
            pretty_name = ANIMAL_NAMES[animal]

            # --- Column headers (top row only) ---
            if row_idx == 0:
                title = "Layer 4" if layer == "L4" else "Layer 5/6"
                ax.set_title(title, fontweight='bold', fontsize=TITLE_SIZE, pad=10)

            if not subset.empty:
                mean_vals = subset['Evoked_Hz_mean']
                sem_vals  = subset['Evoked_Hz_sem'].fillna(0)
                trials    = subset['Trial']

                # Mean line
                ax.plot(trials, mean_vals,
                        color=color, linewidth=2, marker='o',
                        markersize=4, zorder=3)

                # Proper SEM shading
                ax.fill_between(trials,
                                mean_vals - sem_vals,
                                mean_vals + sem_vals,
                                color=color, alpha=0.3, zorder=2,
                                label='±SEM')

                # n label
                ax.text(0.95, 0.95, f"n={n_count}",
                        transform=ax.transAxes, ha='right', va='top',
                        fontsize=FONT_SIZE, fontweight='bold', color='#555555')
            else:
                ax.text(0.5, 0.5, "No Data",
                        transform=ax.transAxes, ha='center', va='center',
                        color='gray', fontsize=FONT_SIZE)

            # Baseline
            ax.axhline(0, color='black', linestyle='--', linewidth=0.8, alpha=0.5)

            # Y-axis label (left column only)
            if col_idx == 0:
                ax.set_ylabel(f"{pretty_name}\n(Hz)",
                              fontweight='bold', fontsize=FONT_SIZE)
            else:
                ax.set_ylabel("")

            # X-axis label (bottom row only)
            if row_idx == 2:
                ax.set_xlabel("Trial #", fontweight='bold', fontsize=FONT_SIZE)
                ax.set_xticks(range(1, MAX_TRIALS + 1))

            ax.tick_params(axis='both', labelsize=FONT_SIZE - 1)
            ax.grid(False)
            sns.despine(ax=ax)

    plt.tight_layout(rect=[0, 0, 1, 1])

    # --- Save ---
    save_dir = Path("results/publication_figures")
    save_dir.mkdir(parents=True, exist_ok=True)

    save_path_svg = save_dir / f"Adaptation_{STIM}_publication.svg"
    save_path_png = save_dir / f"Adaptation_{STIM}_publication.png"

    plt.savefig(save_path_svg, format='svg', bbox_inches='tight')
    plt.savefig(save_path_png, dpi=300, bbox_inches='tight')

    print(f"Saved: {save_path_svg}")
    print(f"Saved: {save_path_png}")

    plt.show()
# Out:
# ...
# GENERATING PUBLICATION PLOT: tail
# ...
# Saved: results\publication_figures\Adaptation_tail_publication.svg
# Saved: results\publication_figures\Adaptation_tail_publication.png

# %%
# First trial

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from pathlib import Path

# =========================================================
# 1. CONFIGURATION
# =========================================================
STIM = "ipsi"

TARGETS = [
    ("a2",   "brush_" + STIM),  
    ("pup1", "brush_" + STIM),
    ("pup2", "brush_" + STIM) 
]

# CRITICAL: Keep the 1.5s window to capture the slow pup response
PRE_WINDOW = 0.5    
POST_WINDOW = 1.5   

ANIMAL_COLORS = {
    "a2":   "#FA91A8",  # Pink
    "pup1": "#A8FA91",  # Green
    "pup2": "#91FAC5"   # Mint
}

# =========================================================
# 2. DATA PROCESSING (TRIAL 1 ONLY)
# =========================================================
t1_data = []
csv_path = Path("data/sessions_local.csv") if Path("data/sessions_local.csv").exists() else Path("data/sessions.csv")
meta = pd.read_csv(csv_path)

print(f"{'='*60}")
print(f"ANALYZING FIRST TRIAL SENSITIVITY ({STIM})")
print(f"{'='*60}")

for session, stim in TARGETS:
    row = meta.loc[(meta['session'] == session) & (meta['stim'] == stim)]
    if len(row) == 0: continue
    row = row.iloc[0]
    
    onsets_path = Path(f"results/summaries/{session}_{stim}_onsets.txt")
    if not onsets_path.exists(): continue
    onsets = np.loadtxt(onsets_path)
    if onsets.ndim == 0: onsets = [onsets]
    
    # SORT and TAKE THE FIRST ONE
    onsets = np.sort(onsets)
    if len(onsets) == 0: continue
    t_first = onsets[0]
    
    phy_dir = Path(row['phy_dir'])
    spike_times = np.load(phy_dir / 'spike_times.npy').flatten() / 30000.0
    spike_clusters = np.load(phy_dir / 'spike_clusters.npy').flatten()
    cluster_info = pd.read_csv(phy_dir / 'cluster_info.tsv', sep='\t')
    
    lbl = 'KSLabel' if 'KSLabel' in cluster_info.columns else 'group'
    valid_units = cluster_info[cluster_info[lbl].isin(['good', 'mua'])]
    
    def get_bound(col): return float(row[col]) if col in row and not pd.isna(row[col]) else None
    l1_bot  = get_bound('l1_end')
    l23_bot = get_bound('l23_end')
    l4_bot  = get_bound('l4_end')
    l6_bot  = get_bound('l6_end')
    if l1_bot is None: l1_bot = get_bound('s1_upper_um')

    for _, unit in valid_units.iterrows():
        uid = unit['cluster_id']
        depth = unit['depth']
        
        layer = "Other"
        if l23_bot is not None and l1_bot is not None and l23_bot <= depth <= l1_bot: layer = "L2/3"
        if l4_bot is not None and l23_bot is not None and l4_bot <= depth < l23_bot: layer = "L4"
        if l6_bot is not None and l4_bot is not None and l6_bot <= depth < l4_bot: layer = "L5/6"

        if layer not in ['L4', 'L5/6']: continue
        
        u_spikes = spike_times[spike_clusters == uid]
        
        # Calculate Trial 1 Rate ONLY
        c_pre = np.sum((u_spikes >= t_first - PRE_WINDOW) & (u_spikes < t_first))
        c_post = np.sum((u_spikes >= t_first) & (u_spikes < t_first + POST_WINDOW))
        
        evoked = (c_post / POST_WINDOW) - (c_pre / PRE_WINDOW)
        
        t1_data.append({
            'Animal': session,
            'Layer': layer,
            'Evoked_Hz': evoked
        })

# =========================================================
# 3. PLOTTING (BAR CHART)
# =========================================================
if len(t1_data) == 0:
    print("❌ ERROR: No units found.")
else:
    df = pd.DataFrame(t1_data)
    
    # Calculate Mean per Animal per Layer
    summary = df.groupby(['Layer', 'Animal'])['Evoked_Hz'].mean().reset_index()
    
    # Print the exact numbers for your presentation
    print("\nMEAN RESPONSE TO FIRST STIMULUS (Hz)")
    print("-" * 40)
    print(summary)
    print("-" * 40)

    # Setup Figure
    sns.set_style("whitegrid")
    plt.figure(figsize=(7, 6))
    
    # Bar Plot
    # hue="Animal" groups the bars side-by-side
    ax = sns.barplot(
        data=summary, 
        x="Layer", 
        y="Evoked_Hz", 
        hue="Animal",
        palette=ANIMAL_COLORS,
        edgecolor="black",
        linewidth=1.5,
        alpha=0.9,
        hue_order=['a2', 'pup1', 'pup2']
    )
    
    # Add Value Labels on top of bars (Visual Learners love this!)
    for container in ax.containers:
        ax.bar_label(container, fmt='%.1f', padding=3, fontweight='bold', fontsize=11)

    # Formatting
    plt.title(f"First Touch Sensitivity ({STIM})", fontsize=16, fontweight='bold', pad=15)
    plt.xlabel("", fontsize=14)
    plt.ylabel(f"Evoked Response (Hz)\n(Window: 0 - {POST_WINDOW}s)", fontsize=12, fontweight='bold')
    
    # Force Y-axis to start at 0
    plt.axhline(0, color='black', linewidth=1.5)
    
    # Clean Legend
    plt.legend(title="", frameon=False, loc='upper right')
    
    sns.despine(left=True)
    
    # Save
    save_dir = Path("results/figures")
    save_dir.mkdir(parents=True, exist_ok=True)
    save_path = save_dir / f"FirstTrial_{STIM}.png"
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    print(f"\n✅ Plot saved to {save_path}")
    plt.show()
# Out:
# ...
# ANALYZING FIRST TRIAL SENSITIVITY (ipsi)
# ...
#
# MEAN RESPONSE TO FIRST STIMULUS (Hz)
# ----------------------------------------
#   Layer Animal  Evoked_Hz
# 0    L4     a2   2.444444
# 1    L4   pup1   2.666667
# 2    L4   pup2  10.000000
# 3  L5/6     a2  17.259259
# 4  L5/6   pup1   1.142857
# 5  L5/6   pup2   0.666667
# ----------------------------------------
#
# ✅ Plot saved to results\figures\FirstTrial_ipsi.png

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import numpy as np
import pandas as pd
from pathlib import Path
from scipy import stats

# =========================================================
# 1. CONFIGURATION
# =========================================================
STIM       = "tail"
ANIMALS    = ["a2", "pup1", "pup2"]
LAYERS     = ["L2/3", "L4", "L5/6"]

ANIMAL_COLORS = {
    "a2":   "#FA91A8",
    "pup1": "#A8FA91",
    "pup2": "#91FAC5",
}
ANIMAL_NAMES = {
    "a2":   "Adult",
    "pup1": "Pup 1",
    "pup2": "Pup 2",
}
LAYER_TITLES = {
    "L2/3": "Layer 2/3",
    "L4":   "Layer 4",
    "L5/6": "Layer 5/6",
}
PANEL_LABELS = ["A", "B", "C"]

MAX_TRIALS  = 8
PRE_WINDOW  = 0.5
POST_WINDOW = 1.5
EPSILON     = 0.5     # Hz — prevents division by zero for silent units
N_BOOTSTRAP = 10_000  # bootstrap iterations for 95% CI

FONT_SIZE  = 10
TITLE_SIZE = 11

plt.rcParams.update({
    'font.size':        FONT_SIZE,
    'font.family':      'Arial',
    'axes.titlesize':   TITLE_SIZE,
    'axes.labelsize':   FONT_SIZE,
    'xtick.labelsize':  FONT_SIZE - 1,
    'ytick.labelsize':  FONT_SIZE - 1,
})

csv_path = (
    Path("data/sessions_local.csv")
    if Path("data/sessions_local.csv").exists()
    else Path("data/sessions.csv")
)
meta = pd.read_csv(csv_path)

save_dir = Path("results/publication_figures")
save_dir.mkdir(parents=True, exist_ok=True)

# =========================================================
# 2. DATA EXTRACTION
# =========================================================
def get_bound(row, col):
    return float(row[col]) if col in row and not pd.isna(row[col]) else None


trial_data = []
stim_name  = f"brush_{STIM}"

print(f"{'='*60}")
print(f"ADAPTATION FIGURE — stimulus: {STIM}")
print(f"{'='*60}")

for session in ANIMALS:
    row = meta.loc[(meta['session'] == session) & (meta['stim'] == stim_name)]
    if len(row) == 0:
        print(f"  Skipping {session} — no metadata entry")
        continue
    row = row.iloc[0]

    onsets_path = Path(f"results/summaries/{session}_{stim_name}_onsets.txt")
    if not onsets_path.exists():
        print(f"  Skipping {session} — onsets file missing")
        continue
    onsets = np.loadtxt(onsets_path)
    if onsets.ndim == 0:
        onsets = np.array([float(onsets)])
    onsets = np.sort(onsets)[:MAX_TRIALS]

    phy_dir = Path(row['phy_dir'])
    if not (phy_dir / 'spike_times.npy').exists():
        print(f"  Skipping {session} — spike_times.npy missing")
        continue

    spike_times    = np.load(phy_dir / 'spike_times.npy').flatten() / 30000.0
    spike_clusters = np.load(phy_dir / 'spike_clusters.npy').flatten()
    cluster_info   = pd.read_csv(phy_dir / 'cluster_info.tsv', sep='\t')

    lbl         = 'KSLabel' if 'KSLabel' in cluster_info.columns else 'group'
    valid_units = cluster_info[cluster_info[lbl].isin(['good', 'mua'])]

    l1_bot  = get_bound(row, 'l1_end') or get_bound(row, 's1_upper_um')
    l23_bot = get_bound(row, 'l23_end')
    l4_bot  = get_bound(row, 'l4_end')
    l6_bot  = get_bound(row, 'l6_end')

    for _, unit in valid_units.iterrows():
        uid   = unit['cluster_id']
        depth = unit['depth']

        layer = "Other"
        if l23_bot is not None and l1_bot  is not None and l23_bot <= depth <= l1_bot:  layer = "L2/3"
        if l4_bot  is not None and l23_bot is not None and l4_bot  <= depth <  l23_bot: layer = "L4"
        if l6_bot  is not None and l4_bot  is not None and l6_bot  <= depth <  l4_bot:  layer = "L5/6"

        if layer not in LAYERS:
            continue

        u_spikes = spike_times[spike_clusters == uid]

        for i, t in enumerate(onsets):
            pre_rate  = np.sum((u_spikes >= t - PRE_WINDOW) & (u_spikes < t)) / PRE_WINDOW
            post_rate = np.sum((u_spikes >= t) & (u_spikes < t + POST_WINDOW)) / POST_WINDOW

            # % change from baseline — normalised, comparable across animals
            pct_change = (post_rate - pre_rate) / (pre_rate + EPSILON) * 100

            trial_data.append({
                'Animal': session,
                'Layer':  layer,
                'Trial':  i + 1,
                'Pct':    pct_change,
            })

# =========================================================
# 3. BOOTSTRAP CI HELPER
# =========================================================
def bootstrap_ci(values, n_boot=N_BOOTSTRAP, ci=95):
    """Bootstrap mean and (ci/2, 100-ci/2) percentile interval."""
    if len(values) == 0:
        return np.nan, np.nan, np.nan
    boots = np.random.choice(values, size=(n_boot, len(values)), replace=True).mean(axis=1)
    lo    = np.percentile(boots, (100 - ci) / 2)
    hi    = np.percentile(boots, 100 - (100 - ci) / 2)
    return np.mean(values), lo, hi

# =========================================================
# 4. BUILD SUMMARY DF WITH BOOTSTRAP CI
# =========================================================
if len(trial_data) == 0:
    print("ERROR: No trial data found. Check paths and layer bounds.")
else:
    df = pd.DataFrame(trial_data)

    records = []
    for animal in ANIMALS:
        for layer in LAYERS:
            for trial in range(1, MAX_TRIALS + 1):
                vals = df[
                    (df['Animal'] == animal) &
                    (df['Layer']  == layer)  &
                    (df['Trial']  == trial)
                ]['Pct'].values

                mean, lo, hi = bootstrap_ci(vals)
                n = len(vals)
                records.append({
                    'Animal': animal, 'Layer': layer, 'Trial': trial,
                    'Mean': mean, 'CI_lo': lo, 'CI_hi': hi, 'n': n,
                })

    summary = pd.DataFrame(records)

    # =========================================================
    # 5. FIGURE  (rows = animals, cols = layers)
    # =========================================================
    n_rows = len(ANIMALS)
    n_cols = len(LAYERS)

    sns.set_style("ticks")
    sns.set_context("paper", font_scale=1.1)

    fig = plt.figure(figsize=(7.2, 9.0))
    gs  = gridspec.GridSpec(
        n_rows, n_cols,
        wspace=0.28, hspace=0.45,
        left=0.11, right=0.97,
        bottom=0.08, top=0.93,
    )

    trial_ticks = np.arange(1, MAX_TRIALS + 1)

    for row_idx, animal in enumerate(ANIMALS):
        for col_idx, layer in enumerate(LAYERS):
            ax     = fig.add_subplot(gs[row_idx, col_idx])
            subset = summary[
                (summary['Animal'] == animal) &
                (summary['Layer']  == layer)
            ].sort_values('Trial')

            color = ANIMAL_COLORS[animal]
            n_units = int(subset['n'].iloc[0]) if not subset.empty else 0

            # ── Panel label A/B/C — top row only ────────────────────
            if row_idx == 0:
                ax.text(
                    -0.18, 1.20, PANEL_LABELS[col_idx],
                    transform=ax.transAxes,
                    fontsize=13, fontweight='bold', va='top',
                )
                ax.set_title(LAYER_TITLES[layer], fontsize=TITLE_SIZE,
                             fontweight='bold', pad=6)

            # ── Row label — left column only ────────────────────────
            if col_idx == 0:
                ax.set_ylabel(
                    f"{ANIMAL_NAMES[animal]}\n% Change from Baseline",
                    fontsize=FONT_SIZE, labelpad=6,
                )
            else:
                ax.set_ylabel("")
                ax.tick_params(axis='y', labelleft=False)

            # ── X label — bottom row only ───────────────────────────
            if row_idx == n_rows - 1:
                ax.set_xlabel("Trial", fontsize=FONT_SIZE)
            ax.set_xticks(trial_ticks)

            if subset.empty or subset['Mean'].isna().all():
                ax.text(0.5, 0.5, "No data", transform=ax.transAxes,
                        ha='center', va='center', color='grey',
                        fontsize=FONT_SIZE)
                sns.despine(ax=ax)
                continue

            trials   = subset['Trial'].values
            means    = subset['Mean'].values
            ci_lo    = subset['CI_lo'].values
            ci_hi    = subset['CI_hi'].values

            # ── Bootstrap CI shading ────────────────────────────────
            ax.fill_between(trials, ci_lo, ci_hi,
                            color=color, alpha=0.25, zorder=2,
                            label='95% CI (bootstrap)')

            # ── Mean line ───────────────────────────────────────────
            ax.plot(trials, means,
                    color=color, linewidth=2,
                    marker='o', markersize=4, zorder=3)

            # ── Linear regression trend line ────────────────────────
            valid     = ~np.isnan(means)
            x_fit     = trials[valid].astype(float)
            y_fit     = means[valid]

            if len(x_fit) >= 3:
                slope, intercept, r, p_val, _ = stats.linregress(x_fit, y_fit)
                y_pred = slope * x_fit + intercept

                ax.plot(x_fit, y_pred,
                        color='#333333', linewidth=1.2,
                        linestyle='--', zorder=4, alpha=0.8)

                # Significance stars
                if   p_val < 0.001: sig = "***"
                elif p_val < 0.01:  sig = "**"
                elif p_val < 0.05:  sig = "*"
                else:               sig = "ns"

                # Slope direction label
                direction = "▼" if slope < 0 else "▲"

                ax.text(
                    0.97, 0.97,
                    f"{direction} {slope:+.1f}%/trial\np={p_val:.2e}  {sig}",
                    transform=ax.transAxes,
                    ha='right', va='top',
                    fontsize=FONT_SIZE - 2,
                    bbox=dict(boxstyle="round", fc="white",
                              ec="black", alpha=0.85),
                )

            # ── Baseline ─────────────────────────────────────────────
            ax.axhline(0, color='black', linestyle='--',
                       linewidth=0.8, alpha=0.4)

            # ── n annotation ─────────────────────────────────────────
            ax.text(0.03, 0.97, f"n={n_units}",
                    transform=ax.transAxes,
                    ha='left', va='top',
                    fontsize=FONT_SIZE - 2,
                    color='#666666')

            ax.set_xlim(0.5, MAX_TRIALS + 0.5)
            sns.despine(ax=ax)

    # ── Save ──────────────────────────────────────────────────────────────────
    save_stem = save_dir / f"Adaptation_{STIM}_publication"
    fig.savefig(f"{save_stem}.svg", format='svg', bbox_inches='tight')
    fig.savefig(f"{save_stem}.png", dpi=300,      bbox_inches='tight')
    plt.close(fig)

    print(f"\n✓ Saved: {save_stem}.svg")
    print(f"✓ Saved: {save_stem}.png")
# Out:
# ...
# ADAPTATION FIGURE — stimulus: tail
# ...
#
# ✓ Saved: results\publication_figures\Adaptation_tail_publication.svg
# ✓ Saved: results\publication_figures\Adaptation_tail_publication.png

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import numpy as np
import pandas as pd
from pathlib import Path
from scipy import stats

# =========================================================
# 1. CONFIGURATION
# =========================================================
STIM_TYPES = ["brush_contra", "brush_ipsi", "brush_tail"]
STIM_LABELS = {
    "brush_contra": "Contralateral",
    "brush_ipsi":   "Ipsilateral",
    "brush_tail":   "Tail",
}

ANIMALS = ["a2", "pup1", "pup2"]
LAYERS  = ["L2/3", "L4", "L5/6"]
LAYER_TITLES = {
    "L2/3": "Layer 2/3",
    "L4":   "Layer 4",
    "L5/6": "Layer 5/6",
}
PANEL_LABELS = ["A", "B", "C"]

ANIMAL_COLORS = {
    "a2":   "#FA91A8",
    "pup1": "#A8FA91",
    "pup2": "#91FAC5",
}
ANIMAL_NAMES = {
    "a2":   "Adult",
    "pup1": "Pup 1",
    "pup2": "Pup 2",
}

MAX_TRIALS   = 8
PRE_WINDOW   = 0.5
POST_WINDOW  = 1.5
N_BOOTSTRAP  = 10_000
MIN_N_TREND  = 5

FONT_SIZE  = 10
TITLE_SIZE = 11

plt.rcParams.update({
    'font.size':        FONT_SIZE,
    'font.family':      'Arial',
    'axes.titlesize':   TITLE_SIZE,
    'axes.labelsize':   FONT_SIZE,
    'xtick.labelsize':  FONT_SIZE - 1,
    'ytick.labelsize':  FONT_SIZE - 1,
})

csv_path = (
    Path("data/sessions_local.csv")
    if Path("data/sessions_local.csv").exists()
    else Path("data/sessions.csv")
)
meta = pd.read_csv(csv_path)

save_dir = Path("results/publication_figures")
save_dir.mkdir(parents=True, exist_ok=True)

# =========================================================
# 2. HELPERS
# =========================================================
def get_bound(row, col):
    return float(row[col]) if col in row and not pd.isna(row[col]) else None


def bootstrap_ci(values, n_boot=N_BOOTSTRAP, ci=95):
    if len(values) == 0:
        return np.nan, np.nan, np.nan
    boots = np.random.choice(values, size=(n_boot, len(values)), replace=True).mean(axis=1)
    lo    = np.percentile(boots, (100 - ci) / 2)
    hi    = np.percentile(boots, 100 - (100 - ci) / 2)
    return np.mean(values), lo, hi


def extract_trial_data(stim_name):
    records = []

    for session in ANIMALS:
        row = meta.loc[(meta['session'] == session) & (meta['stim'] == stim_name)]
        if len(row) == 0:
            print(f"  Skipping {session} — no metadata entry")
            continue
        row = row.iloc[0]

        onsets_path = Path(f"results/summaries/{session}_{stim_name}_onsets.txt")
        if not onsets_path.exists():
            print(f"  Skipping {session} — onsets file missing")
            continue
        onsets = np.loadtxt(onsets_path)
        if onsets.ndim == 0:
            onsets = np.array([float(onsets)])
        onsets = np.sort(onsets)[:MAX_TRIALS]

        phy_dir = Path(row['phy_dir'])
        if not (phy_dir / 'spike_times.npy').exists():
            print(f"  Skipping {session} — spike_times.npy missing")
            continue

        spike_times    = np.load(phy_dir / 'spike_times.npy').flatten() / 30000.0
        spike_clusters = np.load(phy_dir / 'spike_clusters.npy').flatten()
        cluster_info   = pd.read_csv(phy_dir / 'cluster_info.tsv', sep='\t')

        lbl         = 'KSLabel' if 'KSLabel' in cluster_info.columns else 'group'
        valid_units = cluster_info[cluster_info[lbl].isin(['good', 'mua'])]

        l1_bot  = get_bound(row, 'l1_end') or get_bound(row, 's1_upper_um')
        l23_bot = get_bound(row, 'l23_end')
        l4_bot  = get_bound(row, 'l4_end')
        l6_bot  = get_bound(row, 'l6_end')

        for _, unit in valid_units.iterrows():
            uid   = unit['cluster_id']
            depth = unit['depth']

            layer = "Other"
            if l23_bot is not None and l1_bot  is not None and l23_bot <= depth <= l1_bot:  layer = "L2/3"
            if l4_bot  is not None and l23_bot is not None and l4_bot  <= depth <  l23_bot: layer = "L4"
            if l6_bot  is not None and l4_bot  is not None and l6_bot  <= depth <  l4_bot:  layer = "L5/6"

            if layer not in LAYERS:
                continue

            u_spikes = spike_times[spike_clusters == uid]

            for i, t in enumerate(onsets):
                pre_rate  = np.sum((u_spikes >= t - PRE_WINDOW) & (u_spikes < t)) / PRE_WINDOW
                post_rate = np.sum((u_spikes >= t) & (u_spikes < t + POST_WINDOW)) / POST_WINDOW
                evoked_hz = post_rate - pre_rate   # ← raw evoked Hz, no normalisation

                records.append({
                    'Animal': session,
                    'Layer':  layer,
                    'Trial':  i + 1,
                    'Pct':    evoked_hz,
                })

    return pd.DataFrame(records)


def build_summary(df):
    records = []
    for animal in ANIMALS:
        for layer in LAYERS:
            for trial in range(1, MAX_TRIALS + 1):
                vals = df[
                    (df['Animal'] == animal) &
                    (df['Layer']  == layer)  &
                    (df['Trial']  == trial)
                ]['Pct'].values

                mean, lo, hi = bootstrap_ci(vals)
                records.append({
                    'Animal': animal, 'Layer': layer, 'Trial': trial,
                    'Mean': mean, 'CI_lo': lo, 'CI_hi': hi,
                    'n': len(vals),
                })
    return pd.DataFrame(records)

# =========================================================
# 3. COMPUTE SHARED Y RANGE ACROSS ALL STIMULI
# =========================================================
print("Pre-extracting all data to compute shared Y range...")
all_data = {}
for stim in STIM_TYPES:
    print(f"\n  {STIM_LABELS[stim]}")
    all_data[stim] = extract_trial_data(stim)

all_pct = pd.concat(all_data.values())['Pct']
if len(all_pct) > 0:
    y_min = np.floor(np.nanpercentile(all_pct, 1))
    y_max = np.ceil(np.nanpercentile(all_pct, 99))
else:
    y_min, y_max = -10, 30

# =========================================================
# 4. PLOT — one figure per stimulus
# =========================================================
trial_ticks = np.arange(1, MAX_TRIALS + 1)

for stim in STIM_TYPES:
    stim_label = STIM_LABELS[stim]
    df         = all_data[stim]

    print(f"\n{'='*60}")
    print(f"Plotting: {stim_label}")

    if len(df) == 0:
        print("  No data — skipping figure.")
        continue

    summary = build_summary(df)

    sns.set_style("ticks")
    sns.set_context("paper", font_scale=1.1)

    fig = plt.figure(figsize=(7.2, 9.0))
    gs  = gridspec.GridSpec(
        len(ANIMALS), len(LAYERS),
        wspace=0.28, hspace=0.45,
        left=0.13, right=0.97,
        bottom=0.08, top=0.93,
    )

    fig.suptitle(stim_label, fontsize=TITLE_SIZE + 1,
                 fontweight='bold', y=0.97)

    for row_idx, animal in enumerate(ANIMALS):
        for col_idx, layer in enumerate(LAYERS):
            ax     = fig.add_subplot(gs[row_idx, col_idx])
            subset = summary[
                (summary['Animal'] == animal) &
                (summary['Layer']  == layer)
            ].sort_values('Trial')

            color   = ANIMAL_COLORS[animal]
            n_units = int(subset['n'].iloc[0]) if not subset.empty else 0

            if row_idx == 0:
                ax.text(
                    -0.20, 1.20, PANEL_LABELS[col_idx],
                    transform=ax.transAxes,
                    fontsize=13, fontweight='bold', va='top',
                )
                ax.set_title(LAYER_TITLES[layer], fontsize=TITLE_SIZE,
                             fontweight='bold', pad=6)

            if col_idx == 0:
                ax.set_ylabel(
                    f"{ANIMAL_NAMES[animal]}\nEvoked Rate (Hz)",   # ← updated label
                    fontsize=FONT_SIZE, labelpad=6,
                )
            else:
                ax.set_ylabel("")
                ax.tick_params(axis='y', labelleft=False)

            if row_idx == len(ANIMALS) - 1:
                ax.set_xlabel("Trial", fontsize=FONT_SIZE)
            ax.set_xticks(trial_ticks)

            ax.set_ylim(y_min, y_max)
            ax.set_xlim(0.5, MAX_TRIALS + 0.5)

            if subset.empty or subset['Mean'].isna().all():
                ax.text(0.5, 0.5, "No data",
                        transform=ax.transAxes, ha='center', va='center',
                        color='grey', fontsize=FONT_SIZE)
                sns.despine(ax=ax)
                continue

            trials = subset['Trial'].values
            means  = subset['Mean'].values
            ci_lo  = subset['CI_lo'].values
            ci_hi  = subset['CI_hi'].values

            ax.fill_between(trials, ci_lo, ci_hi,
                            color=color, alpha=0.25, zorder=2)

            ax.plot(trials, means,
                    color=color, linewidth=2,
                    marker='o', markersize=4, zorder=3)

            ax.axhline(0, color='black', linestyle='--',
                       linewidth=0.8, alpha=0.4)

            valid = ~np.isnan(means)
            x_fit = trials[valid].astype(float)
            y_fit = means[valid]

            if n_units >= MIN_N_TREND and len(x_fit) >= 3:
                slope, intercept, r, p_val, _ = stats.linregress(x_fit, y_fit)
                y_pred    = slope * x_fit + intercept
                direction = "▼" if slope < 0 else "▲"

                if   p_val < 0.001: sig = "***"
                elif p_val < 0.01:  sig = "**"
                elif p_val < 0.05:  sig = "*"
                else:               sig = "ns"

                ax.plot(x_fit, y_pred,
                        color='#333333', linewidth=1.2,
                        linestyle='--', zorder=4, alpha=0.8)

                ax.text(
                    0.97, 0.97,
                    f"{direction} {slope:+.2f} Hz/trial\np={p_val:.2e}  {sig}",
                    transform=ax.transAxes,
                    ha='right', va='top',
                    fontsize=FONT_SIZE - 2,
                    bbox=dict(boxstyle="round", fc="white",
                              ec="black", alpha=0.85),
                )

            else:
                ax.text(
                    0.97, 0.97,
                    f"n<{MIN_N_TREND}\ntrend not shown",
                    transform=ax.transAxes,
                    ha='right', va='top',
                    fontsize=FONT_SIZE - 2,
                    color='#999999',
                    bbox=dict(boxstyle="round", fc="white",
                              ec="#cccccc", alpha=0.85),
                )

            ax.text(0.03, 0.97, f"n={n_units}",
                    transform=ax.transAxes,
                    ha='left', va='top',
                    fontsize=FONT_SIZE - 2,
                    color='#666666')

            sns.despine(ax=ax)

    stim_short = stim.replace("brush_", "")
    save_stem  = save_dir / f"Adaptation_{stim_short}_publication"
    fig.savefig(f"{save_stem}.svg", format='svg', bbox_inches='tight')
    fig.savefig(f"{save_stem}.png", dpi=300,      bbox_inches='tight')
    plt.close(fig)

    print(f"  ✓ Saved: {save_stem}.svg")
    print(f"  ✓ Saved: {save_stem}.png")

print("\nAll adaptation figures complete.")
# Out:
# Pre-extracting all data to compute shared Y range...
#
#   Contralateral
#
#   Ipsilateral
#
#   Tail
#
# ...
# Plotting: Contralateral
#   ✓ Saved: results\publication_figures\Adaptation_contra_publication.svg
#   ✓ Saved: results\publication_figures\Adaptation_contra_publication.png
#
# ...
# Plotting: Ipsilateral
#   ✓ Saved: results\publication_figures\Adaptation_ipsi_publication.svg
#   ✓ Saved: results\publication_figures\Adaptation_ipsi_publication.png
#
# ...
# Plotting: Tail
#   ✓ Saved: results\publication_figures\Adaptation_tail_publication.svg
#   ✓ Saved: results\publication_figures\Adaptation_tail_publication.png
#
# All adaptation figures complete.

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import numpy as np
import pandas as pd
from pathlib import Path
from scipy import stats

# =========================================================
# 1. CONFIGURATION
# =========================================================
STIM_TYPES = ["brush_contra", "brush_ipsi", "brush_tail"]
STIM_LABELS = {
    "brush_contra": "Contralateral",
    "brush_ipsi":   "Ipsilateral",
    "brush_tail":   "Tail",
}

ANIMALS = ["a2", "pup1", "pup2"]
LAYERS  = ["L2/3", "L4", "L5/6"]
LAYER_TITLES = {
    "L2/3": "Layer 2/3",
    "L4":   "Layer 4",
    "L5/6": "Layer 5/6",
}
PANEL_LABELS = ["A", "B", "C"]

ANIMAL_COLORS = {
    "a2":   "#FA91A8",
    "pup1": "#A8FA91",
    "pup2": "#91FAC5",
}
ANIMAL_NAMES = {
    "a2":   "Adult",
    "pup1": "Pup 1",
    "pup2": "Pup 2",
}

MAX_TRIALS   = 8
PRE_WINDOW   = 0.5
POST_WINDOW  = 1.5
N_BOOTSTRAP  = 10_000
MIN_N_TREND  = 5

FONT_SIZE  = 10
TITLE_SIZE = 11

plt.rcParams.update({
    'font.size':        FONT_SIZE,
    'font.family':      'Arial',
    'axes.titlesize':   TITLE_SIZE,
    'axes.labelsize':   FONT_SIZE,
    'xtick.labelsize':  FONT_SIZE - 1,
    'ytick.labelsize':  FONT_SIZE - 1,
})

csv_path = (
    Path("data/sessions_local.csv")
    if Path("data/sessions_local.csv").exists()
    else Path("data/sessions.csv")
)
meta = pd.read_csv(csv_path)

save_dir = Path("results/publication_figures")
save_dir.mkdir(parents=True, exist_ok=True)

# =========================================================
# 2. HELPERS
# =========================================================
def get_bound(row, col):
    return float(row[col]) if col in row and not pd.isna(row[col]) else None


def bootstrap_ci(values, n_boot=N_BOOTSTRAP, ci=95):
    if len(values) == 0:
        return np.nan, np.nan, np.nan
    boots = np.random.choice(values, size=(n_boot, len(values)), replace=True).mean(axis=1)
    lo    = np.percentile(boots, (100 - ci) / 2)
    hi    = np.percentile(boots, 100 - (100 - ci) / 2)
    return np.mean(values), lo, hi


def extract_trial_data(stim_name):
    records = []

    for session in ANIMALS:
        row = meta.loc[(meta['session'] == session) & (meta['stim'] == stim_name)]
        if len(row) == 0:
            print(f"  Skipping {session} — no metadata entry")
            continue
        row = row.iloc[0]

        onsets_path = Path(f"results/summaries/{session}_{stim_name}_onsets.txt")
        if not onsets_path.exists():
            print(f"  Skipping {session} — onsets file missing")
            continue
        onsets = np.loadtxt(onsets_path)
        if onsets.ndim == 0:
            onsets = np.array([float(onsets)])
        onsets = np.sort(onsets)[:MAX_TRIALS]

        phy_dir = Path(row['phy_dir'])
        if not (phy_dir / 'spike_times.npy').exists():
            print(f"  Skipping {session} — spike_times.npy missing")
            continue

        spike_times    = np.load(phy_dir / 'spike_times.npy').flatten() / 30000.0
        spike_clusters = np.load(phy_dir / 'spike_clusters.npy').flatten()
        cluster_info   = pd.read_csv(phy_dir / 'cluster_info.tsv', sep='\t')

        lbl         = 'KSLabel' if 'KSLabel' in cluster_info.columns else 'group'
        valid_units = cluster_info[cluster_info[lbl].isin(['good', 'mua'])]

        l1_bot  = get_bound(row, 'l1_end') or get_bound(row, 's1_upper_um')
        l23_bot = get_bound(row, 'l23_end')
        l4_bot  = get_bound(row, 'l4_end')
        l6_bot  = get_bound(row, 'l6_end')

        for _, unit in valid_units.iterrows():
            uid   = unit['cluster_id']
            depth = unit['depth']

            layer = "Other"
            if l23_bot is not None and l1_bot  is not None and l23_bot <= depth <= l1_bot:  layer = "L2/3"
            if l4_bot  is not None and l23_bot is not None and l4_bot  <= depth <  l23_bot: layer = "L4"
            if l6_bot  is not None and l4_bot  is not None and l6_bot  <= depth <  l4_bot:  layer = "L5/6"

            if layer not in LAYERS:
                continue

            u_spikes = spike_times[spike_clusters == uid]

            for i, t in enumerate(onsets):
                pre_rate  = np.sum((u_spikes >= t - PRE_WINDOW) & (u_spikes < t)) / PRE_WINDOW
                post_rate = np.sum((u_spikes >= t) & (u_spikes < t + POST_WINDOW)) / POST_WINDOW
                evoked_hz = post_rate - pre_rate

                records.append({
                    'Animal': session,
                    'Layer':  layer,
                    'Trial':  i + 1,
                    'Unit':   f"{session}_{uid}",
                    'Pct':    evoked_hz,
                })

    return pd.DataFrame(records)


def build_summary(df):
    """Bootstrap CI per animal × layer × trial, plus per-unit slopes for t-test."""
    trial_records = []
    slope_records = []

    trial_nums = np.arange(1, MAX_TRIALS + 1, dtype=float)

    for animal in ANIMALS:
        for layer in LAYERS:
            subset = df[(df['Animal'] == animal) & (df['Layer'] == layer)]

            # ── Per-trial bootstrap CI ───────────────────────────────
            for trial in range(1, MAX_TRIALS + 1):
                vals = subset[subset['Trial'] == trial]['Pct'].values
                mean, lo, hi = bootstrap_ci(vals)
                trial_records.append({
                    'Animal': animal, 'Layer': layer, 'Trial': trial,
                    'Mean': mean, 'CI_lo': lo, 'CI_hi': hi,
                    'n': len(vals),
                })

            # ── Per-unit slope ───────────────────────────────────────
            # Fit a line through each unit's 8 trial values individually
            for uid in subset['Unit'].unique():
                unit_data = subset[subset['Unit'] == uid].sort_values('Trial')
                if len(unit_data) < 3:
                    continue
                x = unit_data['Trial'].values.astype(float)
                y = unit_data['Pct'].values
                slope, _, _, _, _ = stats.linregress(x, y)
                slope_records.append({
                    'Animal': animal,
                    'Layer':  layer,
                    'Slope':  slope,
                })

    return pd.DataFrame(trial_records), pd.DataFrame(slope_records)


# =========================================================
# 3. COMPUTE SHARED Y RANGE
# =========================================================
print("Pre-extracting all data...")
all_data = {}
for stim in STIM_TYPES:
    print(f"\n  {STIM_LABELS[stim]}")
    all_data[stim] = extract_trial_data(stim)

all_pct = pd.concat(all_data.values())['Pct']
if len(all_pct) > 0:
    y_min = np.floor(np.nanpercentile(all_pct, 1))
    y_max = np.ceil(np.nanpercentile(all_pct, 99))
else:
    y_min, y_max = -10, 30

# =========================================================
# 4. PLOT
# =========================================================
trial_ticks = np.arange(1, MAX_TRIALS + 1)

for stim in STIM_TYPES:
    stim_label = STIM_LABELS[stim]
    df         = all_data[stim]

    print(f"\n{'='*60}")
    print(f"Plotting: {stim_label}")

    if len(df) == 0:
        print("  No data — skipping.")
        continue

    summary, slopes_df = build_summary(df)

    sns.set_style("ticks")
    sns.set_context("paper", font_scale=1.1)

    fig = plt.figure(figsize=(7.2, 9.0))
    gs  = gridspec.GridSpec(
        len(ANIMALS), len(LAYERS),
        wspace=0.28, hspace=0.45,
        left=0.13, right=0.97,
        bottom=0.08, top=0.93,
    )

    fig.suptitle(stim_label, fontsize=TITLE_SIZE + 1,
                 fontweight='bold', y=0.97)

    for row_idx, animal in enumerate(ANIMALS):
        for col_idx, layer in enumerate(LAYERS):
            ax     = fig.add_subplot(gs[row_idx, col_idx])
            subset = summary[
                (summary['Animal'] == animal) &
                (summary['Layer']  == layer)
            ].sort_values('Trial')

            color   = ANIMAL_COLORS[animal]
            n_units = int(subset['n'].iloc[0]) if not subset.empty else 0

            if row_idx == 0:
                ax.text(-0.20, 1.20, PANEL_LABELS[col_idx],
                        transform=ax.transAxes,
                        fontsize=13, fontweight='bold', va='top')
                ax.set_title(LAYER_TITLES[layer], fontsize=TITLE_SIZE,
                             fontweight='bold', pad=6)

            if col_idx == 0:
                ax.set_ylabel(f"{ANIMAL_NAMES[animal]}\nEvoked Rate (Hz)",
                              fontsize=FONT_SIZE, labelpad=6)
            else:
                ax.set_ylabel("")
                ax.tick_params(axis='y', labelleft=False)

            if row_idx == len(ANIMALS) - 1:
                ax.set_xlabel("Trial", fontsize=FONT_SIZE)
            ax.set_xticks(trial_ticks)
            ax.set_ylim(y_min, y_max)
            ax.set_xlim(0.5, MAX_TRIALS + 0.5)

            if subset.empty or subset['Mean'].isna().all():
                ax.text(0.5, 0.5, "No data",
                        transform=ax.transAxes, ha='center', va='center',
                        color='grey', fontsize=FONT_SIZE)
                sns.despine(ax=ax)
                continue

            trials = subset['Trial'].values
            means  = subset['Mean'].values
            ci_lo  = subset['CI_lo'].values
            ci_hi  = subset['CI_hi'].values

            ax.fill_between(trials, ci_lo, ci_hi,
                            color=color, alpha=0.25, zorder=2)
            ax.plot(trials, means,
                    color=color, linewidth=2,
                    marker='o', markersize=4, zorder=3)
            ax.axhline(0, color='black', linestyle='--',
                       linewidth=0.8, alpha=0.4)

            # ── Per-unit slope t-test ────────────────────────────────
            unit_slopes = slopes_df[
                (slopes_df['Animal'] == animal) &
                (slopes_df['Layer']  == layer)
            ]['Slope'].values

            if n_units >= MIN_N_TREND and len(unit_slopes) >= MIN_N_TREND:
                mean_slope = np.mean(unit_slopes)
                t_stat, p_val = stats.ttest_1samp(unit_slopes, popmean=0)
                direction = "▼" if mean_slope < 0 else "▲"

                if   p_val < 0.001: sig = "***"
                elif p_val < 0.01:  sig = "**"
                elif p_val < 0.05:  sig = "*"
                else:               sig = "ns"

                # Trend line from mean slope through grand mean
                grand_mean = np.nanmean(means)
                x_fit      = trials.astype(float)
                y_pred     = mean_slope * (x_fit - x_fit.mean()) + grand_mean

                ax.plot(x_fit, y_pred,
                        color='#333333', linewidth=1.2,
                        linestyle='--', zorder=4, alpha=0.8)

                ax.text(
                    0.97, 0.97,
                    f"{direction} {mean_slope:+.2f} Hz/trial\n"
                    f"t-test vs 0: p={p_val:.2e}  {sig}",
                    transform=ax.transAxes,
                    ha='right', va='top',
                    fontsize=FONT_SIZE - 2,
                    bbox=dict(boxstyle="round", fc="white",
                              ec="black", alpha=0.85),
                )

            else:
                ax.text(
                    0.97, 0.97,
                    f"n<{MIN_N_TREND}\ntrend not shown",
                    transform=ax.transAxes,
                    ha='right', va='top',
                    fontsize=FONT_SIZE - 2,
                    color='#999999',
                    bbox=dict(boxstyle="round", fc="white",
                              ec="#cccccc", alpha=0.85),
                )

            ax.text(0.03, 0.97, f"n={n_units}",
                    transform=ax.transAxes,
                    ha='left', va='top',
                    fontsize=FONT_SIZE - 2,
                    color='#666666')

            sns.despine(ax=ax)

    stim_short = stim.replace("brush_", "")
    save_stem  = save_dir / f"Adaptation_{stim_short}_publication"
    fig.savefig(f"{save_stem}.svg", format='svg', bbox_inches='tight')
    fig.savefig(f"{save_stem}.png", dpi=300,      bbox_inches='tight')
    plt.close(fig)

    print(f"  ✓ Saved: {save_stem}.svg")
    print(f"  ✓ Saved: {save_stem}.png")

print("\nAll adaptation figures complete.")
# Out:
# Pre-extracting all data...
#
#   Contralateral
#
#   Ipsilateral
#
#   Tail
#
# ...
# Plotting: Contralateral
#   ✓ Saved: results\publication_figures\Adaptation_contra_publication.svg
#   ✓ Saved: results\publication_figures\Adaptation_contra_publication.png
#
# ...
# Plotting: Ipsilateral
#   ✓ Saved: results\publication_figures\Adaptation_ipsi_publication.svg
#   ✓ Saved: results\publication_figures\Adaptation_ipsi_publication.png
#
# ...
# Plotting: Tail
#   ✓ Saved: results\publication_figures\Adaptation_tail_publication.svg
#   ✓ Saved: results\publication_figures\Adaptation_tail_publication.png
#
# All adaptation figures complete.
